# %% [markdown]
# <a href="https://colab.research.google.com/github/rd-code02/data-science-entry-test/blob/main/Q7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Define a class Car
class Car:
    """
    Task 1
    - Define a class named Car with attributes: make, model, year
    - Initialize these attributes in the __init__ method
    - Add a method named describe_car() that prints information about the car as "Year Make Model"
    """

    def __init__(self,make,model,year):  #define a method __init__ with argument make, model and year
        self.make = make                 #assigning
        self.model = model
        self.year = year

    def describe_car(self):              #define a method describe_car
        print(f"Make:{self.make} ,Modle: {self.model} ,Year: {self.year}")

# Task 2
# Create an instance of the Car class with the following attributes and call describe_car method:
# - Make: Toyota, Model: Corolla, Year: 2020

#case1
car1 = Car("Toyota","Corolla","2020")

#case2
car1.describe_car()
# Out:
# Make:Toyota ,Modle: Corolla ,Year: 2020
