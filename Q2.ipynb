# %% [markdown]
# <a href="https://colab.research.google.com/github/rd-code02/data-science-entry-test/blob/main/Q2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Defining find and replace function
def find_and_replace(lst,find_val,replace_val):

    """
    Task 1
    - Create a function that searches for all occurrences of a value (find_val) in a given list (lst) and replaces them with another value (replace_val).
    - lst must be a list.
    - Return the modified list.
    """
    for i in range(len(lst)): #loop through the list
        if lst[i] == find_val: # search for the value to find
            lst[i] = replace_val #replace it with the replacement value
    return lst #return the modified list
'''
# Task 2
# Invoke the function "find_and_replace" using the following scenarios:
# - [1, 2, 3, 4, 2, 2], 2, 5
# - ["apple", "banana", "apple"], "apple", "orange"
'''

#case1
print(find_and_replace([1, 2, 3, 4, 2, 2], 2, 5))

#case2
print(find_and_replace( ["apple", "banana", "apple"], "apple", "orange"))
