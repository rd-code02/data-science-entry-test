# %% [markdown]
# <a href="https://colab.research.google.com/github/rd-code02/data-science-entry-test/blob/main/Q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Defining the function swap
def swap(x, y):

    """
     Task 1
    - Create a function that would swap the value of x and y using only x and y as variables.
    - x and y must be numeric.
    - Return -1 if x and y is not numeric, and
    - print the swapped values if both x and y are numeric.
    """

    # Check if both x and y values are numeric
    if not isinstance(x, (int, float)) or not isinstance(y, (int, float)):
        return -1

    # Swapping values
    x = x + y
    y = x - y
    x = x - y

    #Prining the x and y values
    print("x is", x)
    print("y is", y)

'''
# Task 2
# Invoke the function "swap" using the following scenarios:
# - "Apple", 10
# - 9, 17
'''
#case1 for negative test
final = swap("Apple", 10)
if final == -1:
    print("Negative test case: ", final)

#case2 for positive test
print("Positive test case:")
final = swap(4,9)
# Out:
# Negative test case:  -1
# Positive test case:
# x is 9
# y is 4
